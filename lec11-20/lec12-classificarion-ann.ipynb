# %% [markdown]
# goal:
# how to solve Multi class classification problem using ann with mnist dataset.

# %% [markdown]
# mnist dataset is collection of 70k images

# %% [markdown]
# whenever working with multi-layer classification we add nodes according to classes how much classes we have same number of nodes as well in output. and then probabibilty high of any node from them we call it final output

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://colab.research.google.com/drive/1vwoYg-vedCfl03-9Z5t94WUV2Vpl0buc#scrollTo=XfQT9bVN3IAw
