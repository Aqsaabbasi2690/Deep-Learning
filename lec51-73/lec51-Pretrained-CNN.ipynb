# %% [markdown]
# Pretrained Models in CNN
# ImageNet Dataset | ILSVRC
# 🔹 What Are Pretrained Models?
#
# A pretrained model is a CNN that has:
#
# Already been trained on a huge dataset
#
# Learned general visual features (edges → shapes → objects)
#
# 👉 Instead of training from scratch, we reuse its knowledge.
#
# This idea is called Transfer Learning.
#
# 🔹 Why Pretrained Models Are So Powerful
#
# Training CNN from scratch:
# ❌ Needs millions of images
# ❌ Needs GPUs + weeks
# ❌ Risk of overfitting
#
# Pretrained models:
# ✅ Train faster
# ✅ Need less data
# ✅ Higher accuracy
# ✅ Industry standard
#
# 🖼 ImageNet Dataset
# 🔹 What is ImageNet?
#
# ImageNet is a massive image dataset used to train most famous CNNs.
#
# ImageNet contains:
#
# ~14 million images
#
# 20,000+ categories
#
# 1,000 classes commonly used
#
# Examples:
# 🐶 Dog, 🐱 Cat, 🚗 Car, 🍎 Apple, ✈ Airplane
#
# 🔹 ImageNet Image Size
#
# Most models use:
#
# 224 × 224 × 3
#
# ILSVRC (ImageNet Large Scale Visual Recognition Challenge)
# 🔹 What is ILSVRC?
#
# ILSVRC is a yearly competition where:
#
# Researchers compete on ImageNet
#
# Goal: best image classification accuracy
#
# 🔹 Why ILSVRC Is Important
#
# Birthplace of modern deep learning
#
# Proved CNNs > traditional ML
#
# Introduced famous architectures
#
# Famous ILSVRC Winners
#
# | Year | Model     | Key Idea         |
# | ---- | --------- | ---------------- |
# | 2012 | AlexNet   | Deep CNN + GPU   |
# | 2014 | VGG       | Deeper networks  |
# | 2014 | GoogLeNet | Inception        |
# | 2015 | ResNet    | Skip connections |
# | 2017 | DenseNet  | Feature reuse    |
#
# Popular Pretrained CNN Models
#
# | Model         | 특징 (Key Feature)          |
# | ------------- | ------------------------- |
# | VGG16 / VGG19 | Simple & deep             |
# | ResNet50      | Solves vanishing gradient |
# | Inception     | Multi-scale filters       |
# | MobileNet     | Lightweight (mobile)      |
# | EfficientNet  | Best accuracy vs size     |
#
#
# How Transfer Learning Works
# Step 1: Load Pretrained Model
# from tensorflow.keras.applications import VGG16
#
# base_model = VGG16(
#     weights='imagenet',
#     include_top=False,
#     input_shape=(224,224,3)
# )
#
# Step 2: Freeze Base Layers
# for layer in base_model.layers:
#     layer.trainable = False
#
# Step 3: Add Your Own Classifier
# from tensorflow.keras import layers, models
#
# model = models.Sequential([
#     base_model,
#     layers.Flatten(),
#     layers.Dense(128, activation='relu'),
#     layers.Dense(1, activation='sigmoid')
# ])
#
# Step 4: Train
# model.compile(
#     optimizer='adam',
#     loss='binary_crossentropy',
#     metrics=['accuracy']
# )
#
# 🔹 Fine-Tuning (Advanced 🔥)
#
# Unfreeze top layers
#
# Train with low learning rate
#
# Improves performance
#
# 🧠 Exam One-Liners
#
# Pretrained model: A CNN trained on ImageNet reused for new tasks
#
# ImageNet: Large-scale image dataset with millions of labeled images
#
# ILSVRC: Competition that advanced CNN research
#
# 🧩 Memory Tricks
# ImageNet → Dataset
# ILSVRC → Competition
# Pretrained Model → Saved Brain
#
# 💡 Interview Questions
#
# ❓ Why ImageNet pretrained models work for medical images?
# ✔ Early layers learn general features
#
# ❓ Can we change input size?
# ✔ Yes (with care), but pretrained expects 224×224

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
